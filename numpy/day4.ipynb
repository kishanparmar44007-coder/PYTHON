# %%
import pandas as pd

import numpy as np

# %% [markdown]
# <!-- serise -->
#
#
# <!-- a one dimensional array like tstructer long with indices a table -->

# %% [markdown]
# <!-- data frame  -->
#
# <!-- a one dimensional array(2d) like tstructer long with indices a table -->

# %%
df=pd.DataFrame
df

# %%
print(df)

# %% [markdown]
# <!-- list of dict -->

# %%
df=pd.DataFrame({
    "name" : ["vansh","abhay","dhruvi"],
    "age"  : [20,18,22],
    "marks" : [80,98,94],
})
df

# %%
df["name"]

# %%
df[["name","marks"]]

# %%
df["name"][2]

# %%
df=["marks"]

# %%
df["city"]=["delhi","mumbai","pune"]

# %%
df["age"].dtypes

# %%
type(df)

# %% [markdown]
# <!-- this opersone is not change real data -->

# %%
df["marks"]+2

# %%
df["marks"]%2

# %%
df["marks"]-3

# %%
df["marks"]*2

# %%
df["marks"]/2

# %%
df2=pd.DataFrame([
    ["aryan","vansh","dhruvi"],
    [20,22,18],
    [98,78,86]
])
df2

# %%
df3=pd.DataFrame([
    ["aryan","vansh","dhruvi"],
    [20,22,18],
    [98,78,86],
]),
index=["name","age","marks"]
df3

# %%
df3=pd.DataFrame([
    ["aryan","vansh","dhruvi"],
    [20,22,18],
    [98,78,86],
]),
columns=["name","age","marks"]
df3

# %% [markdown]
# <!-- lol and loc -->
#
# <!-- loc :label  based indexing -->
#
# <!-- lol : interger based indexing -->

# %%
d3=pd.DataFrame([
    ["alice",25,"new york"],
    ["bob",30,"london"],
    ["charlie",22,"parish"]
])
d3
# Out:
#          0   1         2
# 0    alice  25  new york
# 1      bob  30    london
# 2  charlie  22    parish

# %%
d3=pd.DataFrame(d3,columns=["name","age","city"])

# %%
d3=["name"]
d3
# Out:
# ['name']
