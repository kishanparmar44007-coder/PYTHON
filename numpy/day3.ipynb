# %%
import numpy as np

# %%
arr=np.array([10,15,20,25,30])
arr

# %%
arr=([True,False,False,True,True])
arr

# %%
l=[True,False,True,True,False]
l

# %% [markdown]
# <!-- boolean inedx (true value) : -->

# %%
arr[l]
arr

# %%
l2=(arr %2==0)
l2

# %%
arr[l2]

# %%
age=np.array([42,18,22,13,16])
age

# %%
age[age>18]

# %%
age[age==22]

# %%
a2=np.array([[2,5,7],[1,2,9],[6,4,2]])
a2

# %%
l1=[True,False,True]
l1

# %%
a2=[l1]

# %% [markdown]
# <!-- boolean mask  -->

# %%
arr

# %%
l

# %%
print(np.ma.array(arr,mask=l))

# %%
oddnumbers=np.ma.array(arr,map%2==0)

# %%
print(oddnumbers)

# %% [markdown]
# <!-- reshaping array -->

# %%
a2

# %%
# a2 flatten()

# %%
a1d=np.arange(12)
a1d

# %%
a1d.reshape(4,3)

# %%
a1d.reshape(2,-1)

# %% [markdown]
# <!-- 1d to 3d array -->

# %%
a1d.reshape(2,3,2)

# %% [markdown]
# <!-- broadcasting array -->
#
# <!-- smaller array to match  the shape of larger array -->

# %% [markdown]
# <!-- type of broadcasting -->
#
# <!-- 1. scalar broadcasting : one elemant array -->
#
# <!-- 2. vector broadcasting : 1d array -->
#
# <!-- 3. matrix broadcasting : 2d array -->

# %%
s1 =[3]
s1

# %%
s2=[5]
s2

# %%
s3=np.array([6])
s3

# %%
arr+s2

# %%
arr+s1

# %%
arr+8

# %%
arr+s3

# %% [markdown]
# <!-- row vector -->

# %%
a1=np.array([[1,2,3],[4,5,6]])
a1

# %%
a2=np.array([10,20,30])
a2

# %%
print(a1+a2)

# %%
a1=np.array([[1,2,3],[4,5,6]])
a1

# %%
a2=np.array([10,20]).reshape(-1,1)
a2

# %%
print(a1+a2)

# %%
a2.shape=(2,1)
a2

# %% [markdown]
# <!-- matrix broadcasting -->

# %%
a1=np.array([[1],[2]])
a1

# %%
a2=np.array([[10,20,30]])
a2

# %%
print(a1)

# %%
print(a2)

# %%
a3=a1+a2

# %%
print(a3)
