# %%
import numpy as np
import pandas as pd

# in numpy we had 1D = vector and 2D = matrix
# in pandas we    1D = series and 2D = dataframe

# %% [markdown]
# ## 1st part
# - pd.series
# - pd.dataframe (dict of list) and (list of dict = index and column)
# - indexing and slicing with iloc and loc
# - dtypes

# %% [markdown]
# ## 2nd part
# - want to do +,-,*,/,%2 we need to assign if change in df or else just change in output there itself will be shown

# %%
s=pd.Series([33,54,21,87,46])
s

# %%
s[2]

# %%
s[:3]

# %%
# Data frame 2 dict of list AND list of list
df=pd.DataFrame({
    "Name":["Marry","Dhanush","Ram","Ganga"],
    "Age":[22,43,12,64]
})
df

# %%
df["Code"]=["C1","H5","O9","Y7"]
df

# %%
df["Code"]

# %%
df[["Code","Name"]]

# %%
# simple way

# single row, column, value we need iloc or loc
# just single column with name works like df["Name"]

# print(df["Name"][1])
# print(df[1:3])
print(df.iloc[2])
print(df.loc[2,"Name"])

# %%
df.loc[1,"Name"]

# %%
df.loc[3,"Code"]

# %%
df.loc[1:3,"Code"]

# %%
# iloc and loc
df

# %%
print(df.iloc[2:,:])
print(df.iloc[1,0])
print(df.loc[2,"Code"])
print(df.iloc[0:2,1:])

# %%
df.iloc[:3] # only 3 rows no column parameter given

# %%
df.iloc[:2,:2]

# %%
df.iloc[1,0]

# %%
df.iloc[2,2]

# %%
# list of list
# do index not work with columns
dl=pd.DataFrame([
    ["Raju","poppy","jerry"],
    [22,32,12]
],index=["Name","Age"])
dl

# %%
# if want columns than change data frame
ds=pd.DataFrame([
    ["Raju",22],
    ["Jerry",21],
    ["bheeme",23]
],columns=["Name","Age"])
ds

# %%
ds["Name"]
# print(ds.iloc[2]) # full row of bheem
# print(ds.iloc[0:2])
# print(ds.iloc[0:2,0])
# print(ds.iloc[2,0])
# print(ds.loc[2,"Name"])
# print(ds.loc[1])
# print(ds[["Name","Age"]])

# %%
df.dtypes

# %% [markdown]
# # Calculations

# %%
df

# %%
df["Age"]+2

# %%
df

# %%
# want to update in df than assign =

df["Age"]=df["Age"]+2

# %%
df
